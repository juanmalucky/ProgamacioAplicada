# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/restaurant.csv")
df
# Out:
#     First Name  Gender      City            Menu  Amount Frequency
# 0      Wendell    Male     Lagos           Wings   78.87     Daily
# 1      Elliott  Female    Berlin        Beverage   55.18     Often
# 2       Launce  Female     Lagos        Pastries   86.67    Yearly
# 3       Saidee    Male  New York  Butter Chicken   98.50      Once
# 4        Adina    Male     Lagos  Butter Chicken   99.43    Weekly
# ..         ...     ...       ...             ...     ...       ...
# 995    Brendis  Female     Lagos          Burger   95.46      Once
# 996     Arlene    Male    Berlin        Beverage   27.93    Yearly
# 997       Mylo  Female    Berlin          Burger   37.97    Weekly
# 998       Linc  Female   Toronto  Butter Chicken   92.31     Often
# 999   Jeanette    Male   Toronto        Pastries   39.59    Weekly
#
# [1000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  1000 non-null   object
#  1   Gender      1000 non-null   object
#  2   City        1000 non-null   object
#  3   Menu        1000 non-null   object
#  4   Amount      1000 non-null   float64
#  5   Frequency   1000 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 47.0+ KB

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.pivot_table(values = "Amount", index = "Gender", aggfunc="sum")
df.pivot_table(values = "Amount", index = "Gender", aggfunc="mean")
# Out:
#            Amount
# Gender
# Female  51.240913
# Male    49.731139

# %%
df.pivot_table(values = "Amount", index = "Menu", aggfunc="sum")
# Out:
#                  Amount
# Menu
# Beverage        7614.30
# Burger          9244.10
# Butter Chicken  8092.49
# Pastries        8887.49
# Pizza           8887.20
# Wings           7733.27

# %%
df.pivot_table(values = "Amount", index = ["Gender", "Menu"], aggfunc="sum")
# Out:
#                         Amount
# Gender Menu
# Female Beverage        3723.55
#        Burger          4755.31
#        Butter Chicken  4169.49
#        Pastries        3967.74
#        Pizza           3983.62
#        Wings           4098.41
# Male   Beverage        3890.75
#        Burger          4488.79
#        Butter Chicken  3923.00
#        Pastries        4919.75
#        Pizza           4903.58
#        Wings           3634.86

# %%
df.pivot_table(values = "Amount", index = ["Gender", "Menu"], columns = "City", aggfunc="sum")
# Out:
# City                    Berlin    Lagos  New York  Toronto
# Gender Menu
# Female Beverage         702.22  1092.00    859.05  1070.28
#        Burger          1200.84   502.67   1847.74  1204.06
#        Butter Chicken  1177.46  1097.12    751.34  1143.57
#        Pastries         808.39   972.19   1104.76  1082.40
#        Pizza           1061.67  1393.46    756.31   772.18
#        Wings           1325.82   764.44    997.87  1010.28
# Male   Beverage        1241.12   548.78   1118.20   982.65
#        Burger          1167.56   985.57   1255.50  1080.16
#        Butter Chicken  1037.28  1076.48    925.14   884.10
#        Pastries        1479.85  1259.36   1255.81   924.73
#        Pizza           1288.74  1494.36   1077.41  1043.07
#        Wings            805.48   908.83    975.55   945.00

# %%
df.pivot_table(values = "Amount", index = ["Gender", "Menu"], columns = ["Frequency", "City"], aggfunc="sum")
# Out:
# Frequency               Daily                          Monthly          \
# City                   Berlin   Lagos New York Toronto  Berlin   Lagos
# Gender Menu
# Female Beverage        125.27  255.06   281.28  211.46   38.37   40.00
#        Burger          128.66  294.26   168.63  310.22  257.94   52.31
#        Butter Chicken  163.72  144.89   125.17  461.43  174.33   31.41
#        Pastries         45.70  288.77   278.91    8.34  182.42  117.48
#        Pizza           155.51  358.85    15.52  136.13  143.33  346.28
#        Wings           181.84   86.65   130.81  261.15  120.67  135.47
# Male   Beverage        207.63  112.87    78.95  284.43  236.69   34.26
#        Burger          219.04  231.26   233.81   48.81  172.65  262.73
#        Butter Chicken  141.97  115.42   226.05   72.55  245.14  121.78
#        Pastries        238.71  164.95   122.94  164.00   96.03  409.87
#        Pizza           170.04   21.21    99.56  128.19   94.90  269.43
#        Wings           152.69  266.03      NaN  125.80  210.96   65.31
#
# Frequency                                Often          ...   Seldom          \
# City                  New York Toronto  Berlin   Lagos  ... New York Toronto
# Gender Menu                                             ...
# Female Beverage         204.80     NaN   85.93  328.90  ...    73.96   85.80
#        Burger           164.45   25.23  149.10     NaN  ...   411.69  288.86
#        Butter Chicken   143.80   44.14   75.03   75.72  ...    72.73  135.17
#        Pastries         167.19  253.09  219.58  192.28  ...    93.71  254.63
#        Pizza            149.31   31.23  104.24  150.53  ...   115.65  134.79
#        Wings            158.04  274.80  155.18   47.56  ...   142.69  254.52
# Male   Beverage         228.78   99.47  179.08   76.64  ...   235.16   72.68
#        Burger           197.86  101.84  112.69  149.24  ...   190.84  131.43
#        Butter Chicken      NaN  144.11   66.52  252.41  ...    24.99  203.23
#        Pastries          97.13  116.36   87.56   60.08  ...   213.57     NaN
#        Pizza            130.74   77.18  159.30  149.83  ...   205.74  282.21
#        Wings            191.45  103.75   43.14   90.87  ...   138.50    6.30
#
# Frequency              Weekly                           Yearly          \
# City                   Berlin   Lagos New York Toronto  Berlin   Lagos
# Gender Menu
# Female Beverage        158.21   78.39   105.20  232.31     NaN  282.38
#        Burger          216.37   60.64   328.38  120.28   94.90     NaN
#        Butter Chicken  204.37  236.63      NaN  264.56   48.52  168.88
#        Pastries           NaN  113.35   110.98  117.34  150.81  155.90
#        Pizza           297.81  186.07    65.94  200.18  204.01   80.01
#        Wings           144.63  208.18   221.63   41.74  248.01   23.62
# Male   Beverage        217.69  162.07   220.54  191.25  177.72   73.71
#        Burger          219.30  133.10    66.98  142.61  115.25  133.50
#        Butter Chicken  178.34  173.22   301.95  192.91   87.59   19.98
#        Pastries        455.96  230.94   231.33  113.27  260.93  168.04
#        Pizza           198.70  352.93    39.87  123.70  229.18  281.78
#        Wings              NaN   57.66   180.27   64.61  134.41   55.00
#
# Frequency
# City                  New York Toronto
# Gender Menu
# Female Beverage         100.63  199.37
#        Burger           207.72  176.62
#        Butter Chicken   187.00   84.75
#        Pastries         257.55  260.63
#        Pizza            164.92   86.56
#        Wings            101.05  110.93
# Male   Beverage         206.48  155.18
#        Burger           214.24  131.30
#        Butter Chicken    19.56  137.15
#        Pastries         188.03  171.22
#        Pizza            264.03   92.40
#        Wings             62.42  199.04
#
# [12 rows x 28 columns]
