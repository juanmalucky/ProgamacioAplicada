# %%
import pandas as pd

emp = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Employee.csv")
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1010 non-null   object
#  1   department  1010 non-null   object
#  2   position    1010 non-null   object
#  3   salary      1010 non-null   object
# dtypes: object(4)
# memory usage: 31.7+ KB

# %%
emp[["department", "position"]] = emp[["department", "position"]].astype("category")
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1010 non-null   object
#  1   department  1010 non-null   category
#  2   position    1010 non-null   category
#  3   salary      1010 non-null   object
# dtypes: category(2), object(2)
# memory usage: 19.5+ KB

# %%
a = "   happy    ".lstrip()
a
# Out:
# 'happy    '

# %%
a = a.rstrip()
a
# Out:
# 'happy'

# %%
emp["name"]
# Out:
# 0          JEDIDIAH, PALLAS O
# 1       FLORETTE, JODLOWSKI R
# 2            KIZZIE, PAULUS D
# 3           ENNIS, MACQUIST N
# 4            VAIL, HONATSCH R
#                 ...
# 1005           JAMES, BOLAM M
# 1006       CARLYNN, EDDOLLS A
# 1007        ROZELLE, FOSTON S
# 1008           ALARD, EKINS J
# 1009           ALOIN, READE C
# Name: name, Length: 1010, dtype: object

# %%
emp["name"].str.lstrip().str.rstrip()
# Out:
# 0          JEDIDIAH, PALLAS O
# 1       FLORETTE, JODLOWSKI R
# 2            KIZZIE, PAULUS D
# 3           ENNIS, MACQUIST N
# 4            VAIL, HONATSCH R
#                 ...
# 1005           JAMES, BOLAM M
# 1006       CARLYNN, EDDOLLS A
# 1007        ROZELLE, FOSTON S
# 1008           ALARD, EKINS J
# 1009           ALOIN, READE C
# Name: name, Length: 1010, dtype: object

# %%
emp.head(3)
# Out:
#                     name   department          position       salary
# 0     JEDIDIAH, PALLAS O      FINANCE  PYTHON DEVELOPER  $108,156.28
# 1  FLORETTE, JODLOWSKI R    MARKETING          DIRECTOR   $85,000.00
# 2       KIZZIE, PAULUS D  PROCUREMENT          DIRECTOR   $85,000.00

# %%
#emp["name"]
emp["name"].str.replace(',','.')
# Out:
# 0          JEDIDIAH. PALLAS O
# 1       FLORETTE. JODLOWSKI R
# 2            KIZZIE. PAULUS D
# 3           ENNIS. MACQUIST N
# 4            VAIL. HONATSCH R
#                 ...
# 1005           JAMES. BOLAM M
# 1006       CARLYNN. EDDOLLS A
# 1007        ROZELLE. FOSTON S
# 1008           ALARD. EKINS J
# 1009           ALOIN. READE C
# Name: name, Length: 1010, dtype: object

# %%
emp["position"].str.replace("DIRECTOR","SUPERVISOR")
# Out:
# 0        PYTHON DEVELOPER
# 1              SUPERVISOR
# 2              SUPERVISOR
# 3            DATA ANALYST
# 4               DEVELOPER
#               ...
# 1005        SALES ANALYST
# 1006    SENIOR SUPERVISOR
# 1007       JUNIOR MANAGER
# 1008    SENIOR CONSULTANT
# 1009    SENIOR CONSULTANT
# Name: position, Length: 1010, dtype: object

# %%
emp["salary"]
emp["salary"].str.replace('$',' ').str.replace(',', '').astype("float")
# Out:
# 0       108156.28
# 1        85000.00
# 2        85000.00
# 3        76715.61
# 4       117247.37
#           ...
# 1005     61805.46
# 1006    106673.90
# 1007    119079.36
# 1008     95338.97
# 1009     79558.65
# Name: salary, Length: 1010, dtype: float64

# %%
emp["position"]
emp["position"].str.lower()
emp["position"].str.contains('DATA')
emp["position"].str.upper().str.contains('DATA')
mask1 = emp["position"].str.upper().str.contains('DATA')
emp[mask1]
#emp["position"]
# Out:
#                        name       department                 position  \
# 3         ENNIS, MACQUIST N            SALES             DATA ANALYST
# 10    FIDELITY, MACMEARTY I  HUMAN RESOURCES      JUNIOR DATA ANALYST
# 13     CRISTIANO, SMETOUN H        MARKETING      SENIOR DATA ANALYST
# 14         SELA, LEATHLAY A        LOGISTICS              INTERN DATA
# 29           TITOS, LEVAY O            SALES             DATA ANALYST
# ...                     ...              ...                      ...
# 932     BRANDI, PETTIFORD H            SALES             DATA ANALYST
# 946        MOSHE, PADDELL I           DESIGN             DATA ANALYST
# 955         GLENDON, BERN W           DESIGN  CONSULTANT DATA ANALYST
# 959       ROLLIE, BUCKLEY J      PROCUREMENT           DATA SCIENTIST
# 1000   RICORIKI, POURVEER M            SALES             DATA ANALYST
#
#            salary
# 3      $76,715.61
# 10    $119,524.79
# 13     $99,145.34
# 14     $35,000.00
# 29     $45,113.00
# ...

# %%
mask2 = emp["position"].str.startswith("DATA")
emp[mask2]

mask2 = emp["position"].str.endswith("DATA")
emp[mask2]
# Out:
#                 name department     position      salary
# 14  SELA, LEATHLAY A  LOGISTICS  INTERN DATA  $35,000.00

# %%
"I love python".split(" ")
# Out:
# ['I', 'love', 'python']

# %%
emp["name"].str.split(',').str.get(0).str.title().str.strip().str.split(" ").str.get(0)
# Out:
# 0       Jedidiah
# 1       Florette
# 2         Kizzie
# 3          Ennis
# 4           Vail
#           ...
# 1005       James
# 1006     Carlynn
# 1007     Rozelle
# 1008       Alard
# 1009       Aloin
# Name: name, Length: 1010, dtype: object

# %%
emp["lastname"] = emp["name"].str.split(',').str.get(0).str.title()
emp["firstname"] = emp["name"].str.split(',').str.get(1).str.title()
emp
# Out:
#                        name       department           position       salary  \
# 0        JEDIDIAH, PALLAS O          FINANCE   PYTHON DEVELOPER  $108,156.28
# 1     FLORETTE, JODLOWSKI R        MARKETING           DIRECTOR   $85,000.00
# 2          KIZZIE, PAULUS D      PROCUREMENT           DIRECTOR   $85,000.00
# 3         ENNIS, MACQUIST N            SALES       DATA ANALYST   $76,715.61
# 4          VAIL, HONATSCH R           DESIGN          DEVELOPER  $117,247.37
# ...                     ...              ...                ...          ...
# 1005         JAMES, BOLAM M        MARKETING      SALES ANALYST   $61,805.46
# 1006     CARLYNN, EDDOLLS A         ACCOUNTS    SENIOR DIRECTOR  $106,673.90
# 1007      ROZELLE, FOSTON S  HUMAN RESOURCES     JUNIOR MANAGER  $119,079.36
# 1008         ALARD, EKINS J        MARKETING  SENIOR CONSULTANT   $95,338.97
# 1009         ALOIN, READE C      PROCUREMENT  SENIOR CONSULTANT   $79,558.65
#
#       lastname     firstname
# ...

# %%
emp["name"].str.split(",", expand = True)
emp[["lastname", "firstname"]] = emp["name"].str.split(",", expand = True)
emp
# Out:
#                        name       department           position       salary  \
# 0        JEDIDIAH, PALLAS O          FINANCE   PYTHON DEVELOPER  $108,156.28
# 1     FLORETTE, JODLOWSKI R        MARKETING           DIRECTOR   $85,000.00
# 2          KIZZIE, PAULUS D      PROCUREMENT           DIRECTOR   $85,000.00
# 3         ENNIS, MACQUIST N            SALES       DATA ANALYST   $76,715.61
# 4          VAIL, HONATSCH R           DESIGN          DEVELOPER  $117,247.37
# ...                     ...              ...                ...          ...
# 1005         JAMES, BOLAM M        MARKETING      SALES ANALYST   $61,805.46
# 1006     CARLYNN, EDDOLLS A         ACCOUNTS    SENIOR DIRECTOR  $106,673.90
# 1007      ROZELLE, FOSTON S  HUMAN RESOURCES     JUNIOR MANAGER  $119,079.36
# 1008         ALARD, EKINS J        MARKETING  SENIOR CONSULTANT   $95,338.97
# 1009         ALOIN, READE C      PROCUREMENT  SENIOR CONSULTANT   $79,558.65
#
#       lastname     firstname
# ...

# %%
emp["position"].str.split(" ", expand = True).head(6)
emp["position"].str.split(" ", expand = True, n = 1).head(6)
# Out:
#            0          1
# 0     PYTHON  DEVELOPER
# 1   DIRECTOR       None
# 2   DIRECTOR       None
# 3       DATA    ANALYST
# 4  DEVELOPER       None
# 5        WEB   DESIGNER
