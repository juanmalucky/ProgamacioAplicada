# %%
import pandas as pd
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta
# Out:
#      first name last name  gender    reg date        last login  followers  \
# 0       Corilla  Leuchars  Female   2/11/2011   2020-05-14 3:51      24536
# 1       Forster      Gush    Male    4/2/2015   2020-07-11 7:41       8479
# 2       Everard    Jowers    Male  11/14/2018  2020-05-31 17:36       9356
# 3           Bob  Threader    Male   6/13/2019  2020-07-04 16:19      33319
# 4        Deeann  Standell  Female   4/26/2011   2020-10-03 6:16       2908
# ...         ...       ...     ...         ...               ...        ...
# 1011       Lars     Crisp    Male  12/30/2012   2020-12-11 8:20        787
# 1012       Yvon   Goodbur    Male   9/29/2011  2020-09-20 17:36      18906
# 1013     Pattie     Goody  Female   11/9/2015  2020-07-07 14:41      32425
# 1014        Sol  Andrysek    Male   2/19/2011  2020-10-18 16:06        475
# 1015     Regine  Bernholt  Female  11/15/2013  2020-05-23 14:23      19535
#
#       posts Influencer         Country
# ...

# %%
insta.describe()
# Out:
#           followers        posts
# count   1016.000000  1016.000000
# mean   19182.502953  3824.416339
# std    11018.923176  2210.540015
# min      336.000000    96.000000
# 25%     9259.000000  1885.750000
# 50%    19589.000000  3932.000000
# 75%    28463.250000  5781.500000
# max    37995.000000  7587.000000

# %%
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first name  1016 non-null   object
#  1   last name   1016 non-null   object
#  2   gender      979 non-null    object
#  3   reg date    1016 non-null   object
#  4   last login  1016 non-null   object
#  5   followers   1016 non-null   int64
#  6   posts       1016 non-null   int64
#  7   Influencer  994 non-null    object
#  8   Country     1004 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 71.6+ KB

# %%
insta
# Out:
#      first name last name  gender    reg date        last login  followers  \
# 0       Corilla  Leuchars  Female   2/11/2011   2020-05-14 3:51      24536
# 1       Forster      Gush    Male    4/2/2015   2020-07-11 7:41       8479
# 2       Everard    Jowers    Male  11/14/2018  2020-05-31 17:36       9356
# 3           Bob  Threader    Male   6/13/2019  2020-07-04 16:19      33319
# 4        Deeann  Standell  Female   4/26/2011   2020-10-03 6:16       2908
# ...         ...       ...     ...         ...               ...        ...
# 1011       Lars     Crisp    Male  12/30/2012   2020-12-11 8:20        787
# 1012       Yvon   Goodbur    Male   9/29/2011  2020-09-20 17:36      18906
# 1013     Pattie     Goody  Female   11/9/2015  2020-07-07 14:41      32425
# 1014        Sol  Andrysek    Male   2/19/2011  2020-10-18 16:06        475
# 1015     Regine  Bernholt  Female  11/15/2013  2020-05-23 14:23      19535
#
#       posts Influencer         Country
# ...

# %%
insta["reg date"] = pd.to_datetime(insta["reg date"])
insta
# Out:
#      first name last name  gender   reg date        last login  followers  \
# 0       Corilla  Leuchars  Female 2011-02-11   2020-05-14 3:51      24536
# 1       Forster      Gush    Male 2015-04-02   2020-07-11 7:41       8479
# 2       Everard    Jowers    Male 2018-11-14  2020-05-31 17:36       9356
# 3           Bob  Threader    Male 2019-06-13  2020-07-04 16:19      33319
# 4        Deeann  Standell  Female 2011-04-26   2020-10-03 6:16       2908
# ...         ...       ...     ...        ...               ...        ...
# 1011       Lars     Crisp    Male 2012-12-30   2020-12-11 8:20        787
# 1012       Yvon   Goodbur    Male 2011-09-29  2020-09-20 17:36      18906
# 1013     Pattie     Goody  Female 2015-11-09  2020-07-07 14:41      32425
# 1014        Sol  Andrysek    Male 2011-02-19  2020-10-18 16:06        475
# 1015     Regine  Bernholt  Female 2013-11-15  2020-05-23 14:23      19535
#
#       posts Influencer         Country
# 0       462      False          Brazil
# ...

# %%
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first name  1016 non-null   object
#  1   last name   1016 non-null   object
#  2   gender      979 non-null    object
#  3   reg date    1016 non-null   datetime64[ns]
#  4   last login  1016 non-null   object
#  5   followers   1016 non-null   int64
#  6   posts       1016 non-null   int64
#  7   Influencer  994 non-null    object
#  8   Country     1004 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 71.6+ KB

# %%
insta["last login"] = pd.to_datetime(insta["last login"])
insta
# Out:
#      first name last name  gender   reg date          last login  followers  \
# 0       Corilla  Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1       Forster      Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 2       Everard    Jowers    Male 2018-11-14 2020-05-31 17:36:00       9356
# 3           Bob  Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 4        Deeann  Standell  Female 2011-04-26 2020-10-03 06:16:00       2908
# ...         ...       ...     ...        ...                 ...        ...
# 1011       Lars     Crisp    Male 2012-12-30 2020-12-11 08:20:00        787
# 1012       Yvon   Goodbur    Male 2011-09-29 2020-09-20 17:36:00      18906
# 1013     Pattie     Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1014        Sol  Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
# 1015     Regine  Bernholt  Female 2013-11-15 2020-05-23 14:23:00      19535
#
#       posts Influencer         Country
# ...

# %%
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first name  1016 non-null   object
#  1   last name   1016 non-null   object
#  2   gender      979 non-null    object
#  3   reg date    1016 non-null   datetime64[ns]
#  4   last login  1016 non-null   datetime64[ns]
#  5   followers   1016 non-null   int64
#  6   posts       1016 non-null   int64
#  7   Influencer  994 non-null    object
#  8   Country     1004 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(5)
# memory usage: 71.6+ KB

# %%
insta["gender"].nunique()
# Out:
# 2

# %%
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta
# Out:
#      first name last name  gender   reg date          last login  followers  \
# 0       Corilla  Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1       Forster      Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 2       Everard    Jowers    Male 2018-11-14 2020-05-31 17:36:00       9356
# 3           Bob  Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 4        Deeann  Standell  Female 2011-04-26 2020-10-03 06:16:00       2908
# ...         ...       ...     ...        ...                 ...        ...
# 1011       Lars     Crisp    Male 2012-12-30 2020-12-11 08:20:00        787
# 1012       Yvon   Goodbur    Male 2011-09-29 2020-09-20 17:36:00      18906
# 1013     Pattie     Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1014        Sol  Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
# 1015     Regine  Bernholt  Female 2013-11-15 2020-05-23 14:23:00      19535
#
#       posts Influencer         Country
# ...

# %%
insta["Influencer"] = insta["Influencer"].astype("bool")
insta
# Out:
#      first name last name  gender   reg date          last login  followers  \
# 0       Corilla  Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1       Forster      Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 2       Everard    Jowers    Male 2018-11-14 2020-05-31 17:36:00       9356
# 3           Bob  Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 4        Deeann  Standell  Female 2011-04-26 2020-10-03 06:16:00       2908
# ...         ...       ...     ...        ...                 ...        ...
# 1011       Lars     Crisp    Male 2012-12-30 2020-12-11 08:20:00        787
# 1012       Yvon   Goodbur    Male 2011-09-29 2020-09-20 17:36:00      18906
# 1013     Pattie     Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1014        Sol  Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
# 1015     Regine  Bernholt  Female 2013-11-15 2020-05-23 14:23:00      19535
#
#       posts  Influencer         Country
# ...

# %%
####Refine records by condition

insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv')
insta
# Out:
#      first name last name  gender    reg date        last login  followers  \
# 0       Corilla  Leuchars  Female   2/11/2011   2020-05-14 3:51      24536
# 1       Forster      Gush    Male    4/2/2015   2020-07-11 7:41       8479
# 2       Everard    Jowers    Male  11/14/2018  2020-05-31 17:36       9356
# 3           Bob  Threader    Male   6/13/2019  2020-07-04 16:19      33319
# 4        Deeann  Standell  Female   4/26/2011   2020-10-03 6:16       2908
# ...         ...       ...     ...         ...               ...        ...
# 1011       Lars     Crisp    Male  12/30/2012   2020-12-11 8:20        787
# 1012       Yvon   Goodbur    Male   9/29/2011  2020-09-20 17:36      18906
# 1013     Pattie     Goody  Female   11/9/2015  2020-07-07 14:41      32425
# 1014        Sol  Andrysek    Male   2/19/2011  2020-10-18 16:06        475
# 1015     Regine  Bernholt  Female  11/15/2013  2020-05-23 14:23      19535
#
#       posts Influencer         Country
# ...

# %%
insta = pd.read_csv('/content/drive/MyDrive/udmy/dataAnalisys/Instagram.csv', parse_dates = ["reg date", "last login"])
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first name  1016 non-null   object
#  1   last name   1016 non-null   object
#  2   gender      979 non-null    object
#  3   reg date    1016 non-null   datetime64[ns]
#  4   last login  1016 non-null   datetime64[ns]
#  5   followers   1016 non-null   int64
#  6   posts       1016 non-null   int64
#  7   Influencer  994 non-null    object
#  8   Country     1004 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(5)
# memory usage: 71.6+ KB

# %%
insta["gender"] = insta["gender"].astype("category")
insta["Country"] = insta["Country"].astype("category")
insta["Influencer"] = insta["Influencer"].astype("bool")
insta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first name  1016 non-null   object
#  1   last name   1016 non-null   object
#  2   gender      979 non-null    category
#  3   reg date    1016 non-null   datetime64[ns]
#  4   last login  1016 non-null   datetime64[ns]
#  5   followers   1016 non-null   int64
#  6   posts       1016 non-null   int64
#  7   Influencer  1016 non-null   bool
#  8   Country     1004 non-null   category
# dtypes: bool(1), category(2), datetime64[ns](2), int64(2), object(2)
# memory usage: 51.2+ KB

# %%
insta.head(3)
# Out:
#   first name last name  gender   reg date          last login  followers  \
# 0    Corilla  Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1    Forster      Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 2    Everard    Jowers    Male 2018-11-14 2020-05-31 17:36:00       9356
#
#    posts  Influencer         Country
# 0    462       False          Brazil
# 1   2581        True   United States
# 2   6874       False  United Kingdom

# %%
insta["gender"] == "Male"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1011     True
# 1012     True
# 1013    False
# 1014     True
# 1015    False
# Name: gender, Length: 1016, dtype: bool

# %%
insta["gender"] == "Male"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1011     True
# 1012     True
# 1013    False
# 1014     True
# 1015    False
# Name: gender, Length: 1016, dtype: bool

# %%
mask = insta["Country"] == "United States"
insta[mask]
# Out:
#      first name    last name  gender   reg date          last login  \
# 1       Forster         Gush    Male 2015-04-02 2020-07-11 07:41:00
# 8         Celia       Yurkov  Female 2013-02-02 2020-08-05 14:03:00
# 22        Berte        Audry  Female 2019-09-08 2020-11-03 08:41:00
# 42       Lauree      Berkery  Female 2015-10-08 2020-11-20 06:31:00
# 58      Bronnie      Soitoux    Male 2012-08-10 2020-10-12 13:41:00
# ...         ...          ...     ...        ...                 ...
# 945        Gwyn      Walkley  Female 2012-09-07 2020-06-08 17:13:00
# 963     Ruperto       Tuting    Male 2018-03-29 2020-09-08 21:07:00
# 968        Rick  Claringbold    Male 2012-04-03 2020-11-29 09:35:00
# 986       Viola    Gilhoolie  Female 2020-05-25 2020-10-16 16:53:00
# 1013     Pattie        Goody  Female 2015-11-09 2020-07-07 14:41:00
#
#       followers  posts  Influencer        Country
# 1          8479   2581        True  United States
# ...

# %%
mask = insta["Country"] != "United States"
insta[mask]
# Out:
#      first name  last name  gender   reg date          last login  followers  \
# 0       Corilla   Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 2       Everard     Jowers    Male 2018-11-14 2020-05-31 17:36:00       9356
# 3           Bob   Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 4        Deeann   Standell  Female 2011-04-26 2020-10-03 06:16:00       2908
# 5         Ashla  Ellingham  Female 2015-07-22 2020-12-12 03:10:00      15251
# ...         ...        ...     ...        ...                 ...        ...
# 1010    Thaxter    Fancett    Male 2014-04-10 2020-11-15 06:36:00      27146
# 1011       Lars      Crisp    Male 2012-12-30 2020-12-11 08:20:00        787
# 1012       Yvon    Goodbur    Male 2011-09-29 2020-09-20 17:36:00      18906
# 1014        Sol   Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
# 1015     Regine   Bernholt  Female 2013-11-15 2020-05-23 14:23:00      19535
#
#       posts  Influencer         Country
# ...

# %%
##Refine Records using Multiple conditions - AND

(insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31")
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1011    False
# 1012    False
# 1013    False
# 1014    False
# 1015    False
# Length: 1016, dtype: bool

# %%
mask = (insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31")
insta[mask]
# Out:
#      first name  last name gender   reg date          last login  followers  \
# 2       Everard     Jowers   Male 2018-11-14 2020-05-31 17:36:00       9356
# 3           Bob   Threader   Male 2019-06-13 2020-07-04 16:19:00      33319
# 15        Rolph    Ellcome   Male 2017-01-16 2020-11-11 13:25:00      26221
# 16      Huberto    Ramelot   Male 2016-02-02 2020-07-11 18:48:00      10136
# 17       Morgen   Slamaker   Male 2019-04-09 2020-07-23 10:05:00       3070
# ...         ...        ...    ...        ...                 ...        ...
# 995    Sherwood    Wareing   Male 2018-09-27 2020-08-27 15:35:00       7493
# 996     Delbert     Dorkin   Male 2016-01-01 2020-07-04 05:37:00      23140
# 997       Hakim    Calvard   Male 2016-08-13 2020-12-13 18:45:00      25492
# 1002     Osmund     Gebuhr   Male 2020-07-28 2020-12-01 13:52:00       3012
# 1006       Eben  Tolomelli   Male 2020-01-26 2020-11-02 17:51:00       6954
#
#       posts  Influencer         Country
# ...

# %%
mask = (insta["gender"] == "Male") & (insta["reg date"] > "2015-12-31") & (insta["Country"] == "United States")
insta[mask]
# Out:
#     first name    last name gender   reg date          last login  followers  \
# 71       Cozmo      Garrold   Male 2017-09-27 2020-09-10 15:34:00      27795
# 187       Kyle     Filyukov   Male 2018-11-16 2020-10-24 05:15:00      26932
# 217      Terri        Fonte   Male 2017-09-03 2020-09-07 16:21:00      37839
# 343      Franz        Pavie   Male 2018-10-14 2020-09-21 05:01:00       1014
# 367     Morten     Le Franc   Male 2019-08-20 2020-06-06 00:24:00      37124
# 455    Frankie       Davson   Male 2020-03-29 2020-08-06 09:56:00      11017
# 474     Jordan        Plews   Male 2017-08-31 2020-12-08 15:15:00      21143
# 523     Benito      Lumsdon   Male 2019-06-22 2020-06-01 14:53:00      27564
# 534       Bert     Woolvett   Male 2020-02-25 2020-12-20 20:13:00      11389
# 575     Tammie     Whiterod   Male 2020-08-04 2020-09-03 04:05:00      14145
# 587     Harald        Jewel   Male 2018-05-23 2020-05-20 10:18:00      17293
# ...

# %%
mask1 = insta["gender"] == "Male"
mask2 = insta["reg date"] > "2015-12-31"
mask3 = insta["Country"] == "United States"
insta[mask1 & mask2 & mask3]
# Out:
#     first name    last name gender   reg date          last login  followers  \
# 71       Cozmo      Garrold   Male 2017-09-27 2020-09-10 15:34:00      27795
# 187       Kyle     Filyukov   Male 2018-11-16 2020-10-24 05:15:00      26932
# 217      Terri        Fonte   Male 2017-09-03 2020-09-07 16:21:00      37839
# 343      Franz        Pavie   Male 2018-10-14 2020-09-21 05:01:00       1014
# 367     Morten     Le Franc   Male 2019-08-20 2020-06-06 00:24:00      37124
# 455    Frankie       Davson   Male 2020-03-29 2020-08-06 09:56:00      11017
# 474     Jordan        Plews   Male 2017-08-31 2020-12-08 15:15:00      21143
# 523     Benito      Lumsdon   Male 2019-06-22 2020-06-01 14:53:00      27564
# 534       Bert     Woolvett   Male 2020-02-25 2020-12-20 20:13:00      11389
# 575     Tammie     Whiterod   Male 2020-08-04 2020-09-03 04:05:00      14145
# 587     Harald        Jewel   Male 2018-05-23 2020-05-20 10:18:00      17293
# ...

# %%
##### Select spacific columns after a condition #####################

mask = insta["gender"] == "Female"
mask1 = insta["Influencer"]
insta[mask1 & mask2][["first name", "gender", "Influencer"]]
# Out:
#      first name  gender  Influencer
# 11       Sheila     NaN        True
# 13     Cristina  Female        True
# 15        Rolph    Male        True
# 16      Huberto    Male        True
# 26        Betty  Female        True
# ...         ...     ...         ...
# 995    Sherwood    Male        True
# 998        Suki  Female        True
# 1003   Fionnula  Female        True
# 1004   Mignonne  Female        True
# 1007      Bibby  Female        True
#
# [216 rows x 3 columns]

# %%
####Refine Dataframe using multiple conditions#####  OR condition

##Print out users from SouthAfrica who have over 35000 followers

mask1 = insta["Country"] == "South Africa"
mask1 = insta["followers"] > 35000
#insta[mask1 | mask2]
#insta[mask1 | mask2][["first name", "Country", "followers"]].head(20)
#insta[mask1 | mask2][["first name", "Country", "followers"]]
insta[mask1 | mask2][["first name", "Country", "followers"]].count()
# Out:
# first name    513
# Country       506
# followers     513
# dtype: int64

# %%
mask1 = insta["Country"] == "United States"
mask2 = insta["Country"] == "Brazil"
mask3 = insta["Country"] == "Australia"
insta[mask1 | mask2 | mask3]
# Out:
#      first name  last name  gender   reg date          last login  followers  \
# 0       Corilla   Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1       Forster       Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 3           Bob   Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 5         Ashla  Ellingham  Female 2015-07-22 2020-12-12 03:10:00      15251
# 8         Celia     Yurkov  Female 2013-02-02 2020-08-05 14:03:00       5977
# ...         ...        ...     ...        ...                 ...        ...
# 1002     Osmund     Gebuhr    Male 2020-07-28 2020-12-01 13:52:00       3012
# 1003   Fionnula  Elderidge  Female 2019-12-04 2020-08-10 16:02:00      24112
# 1004   Mignonne      Jancy  Female 2016-06-07 2020-07-08 04:24:00      32257
# 1013     Pattie      Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1014        Sol   Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
#
#       posts  Influencer        Country
# ...

# %%
#insta["Country"].isin(["Australia", "United States", "Brazil"])
mask1 = insta["Country"].isin(["Australia", "United States", "Brazil"])
insta[mask1]
# Out:
#      first name  last name  gender   reg date          last login  followers  \
# 0       Corilla   Leuchars  Female 2011-02-11 2020-05-14 03:51:00      24536
# 1       Forster       Gush    Male 2015-04-02 2020-07-11 07:41:00       8479
# 3           Bob   Threader    Male 2019-06-13 2020-07-04 16:19:00      33319
# 5         Ashla  Ellingham  Female 2015-07-22 2020-12-12 03:10:00      15251
# 8         Celia     Yurkov  Female 2013-02-02 2020-08-05 14:03:00       5977
# ...         ...        ...     ...        ...                 ...        ...
# 1002     Osmund     Gebuhr    Male 2020-07-28 2020-12-01 13:52:00       3012
# 1003   Fionnula  Elderidge  Female 2019-12-04 2020-08-10 16:02:00      24112
# 1004   Mignonne      Jancy  Female 2016-06-07 2020-07-08 04:24:00      32257
# 1013     Pattie      Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1014        Sol   Andrysek    Male 2011-02-19 2020-10-18 16:06:00        475
#
#       posts  Influencer        Country
# ...

# %%
#insta["Country"].isnull()
df = insta["Country"].isnull()
insta[df]
# Out:
#     first name last name  gender   reg date          last login  followers  \
# 4       Deeann  Standell  Female 2011-04-26 2020-10-03 06:16:00       2908
# 18        Enid   Enstone  Female 2017-02-12 2020-05-10 19:26:00        402
# 32     Chrisse   Wardley    Male 2013-01-05 2020-05-24 18:52:00      14855
# 50      Revkah    Mendus  Female 2016-04-05 2020-08-28 16:16:00       3518
# 103     Durant   Milmore    Male 2019-08-30 2020-06-26 03:44:00      31349
# 104    Barnaby     Cooke    Male 2010-07-25 2020-12-22 15:11:00      29452
# 105     Finley    d'Arcy    Male 2017-10-24 2020-07-30 02:47:00      32102
# 106   Gratiana     Artus     NaN 2012-04-19 2020-05-19 18:06:00      37324
# 107        Pru   Wescott  Female 2016-12-13 2020-10-26 04:59:00      11825
# 128      Clerc   McGooch    Male 2016-11-16 2020-07-26 00:17:00      18047
# 129       Mufi  Schellig  Female 2011-06-09 2020-05-22 10:08:00      24053
# ...

# %%
df2 = insta["posts"].isnull()
insta[df2]
# Out:
# Empty DataFrame
# Columns: [first name, last name, gender, reg date, last login, followers, posts, Influencer, Country]
# Index: []

# %%
mask1 = insta["Country"].notnull()
insta[mask1].count()
# Out:
# first name    1004
# last name     1004
# gender         968
# reg date      1004
# last login    1004
# followers     1004
# posts         1004
# Influencer    1004
# Country       1004
# dtype: int64

# %%
mask = insta["reg date"].between("2016--01-01", "2016-02-29")
#insta[mask].sort_values("reg date")
#insta[mask] [["first name", "reg date"]].sort_values("reg date")
insta[mask] [["first name", "reg date"]].sort_values("reg date").count()
# Out:
# first name    11
# reg date      11
# dtype: int64

# %%
insta.sort_values("first name", inplace = True)
insta["first name"]
# Out:
# 149        Abba
# 243       Abbie
# 83        Abbye
# 746        Abel
# 354        Abel
#          ...
# 529     Zachery
# 339    Zebadiah
# 415     Zebulen
# 656       Zelig
# 152        Zita
# Name: first name, Length: 1016, dtype: object

# %%
#insta["first name"].duplicated().head(10)
insta[insta["first name"].duplicated()]
# Out:
#      first name   last name  gender   reg date          last login  followers  \
# 354        Abel      Puttan    Male 2019-05-26 2020-09-16 14:39:00      10158
# 764        Abra       Algie  Female 2013-02-18 2020-12-04 02:45:00       6549
# 697        Abra    Bleythin  Female 2017-04-12 2020-12-16 19:39:00      28690
# 509      Alfons       Gever    Male 2020-08-12 2020-05-22 23:30:00       2000
# 88       Alicia  Gilffillan  Female 2012-07-26 2020-05-29 10:58:00       6706
# ...         ...         ...     ...        ...                 ...        ...
# 886        Vale    Agronski    Male 2019-02-14 2020-06-11 19:54:00      33207
# 866       Viola     Mixture  Female 2018-12-18 2020-12-21 23:10:00      23396
# 1008      Waite   Gainsboro    Male 2013-06-15 2020-09-05 12:10:00      22733
# 856      Yasmin      Deegan  Female 2010-03-19 2020-06-21 10:54:00      10118
# 1012       Yvon     Goodbur    Male 2011-09-29 2020-09-20 17:36:00      18906
#
# ...

# %%
dup = insta.duplicated()
insta[dup]
# Out:
#      first name   last name  gender   reg date          last login  followers  \
# 962       Bibby      Siward  Female 2020-10-19 2020-08-14 00:14:00       1668
# 1000    Devonne      Orritt  Female 2018-06-20 2020-05-10 14:25:00      37812
# 961        Eben   Tolomelli    Male 2020-01-26 2020-11-02 17:51:00       6954
# 1003   Fionnula   Elderidge  Female 2019-12-04 2020-08-10 16:02:00      24112
# 1001   Gayelord    McKernon    Male 2012-02-20 2020-09-22 18:50:00       9057
# 858        Lars       Crisp    Male 2012-12-30 2020-12-11 08:20:00        787
# 959    Mignonne       Jancy  Female 2016-06-07 2020-07-08 04:24:00      32257
# 1002     Osmund      Gebuhr    Male 2020-07-28 2020-12-01 13:52:00       3012
# 1013     Pattie       Goody  Female 2015-11-09 2020-07-07 14:41:00      32425
# 1015     Regine    Bernholt  Female 2013-11-15 2020-05-23 14:23:00      19535
# 1005       Shae  Blackaller  Female 2020-02-25 2020-12-18 20:27:00       2638
# ...

# %%
insta.drop_duplicates()
# Out:
#     first name last name  gender   reg date          last login  followers  \
# 149       Abba     Savin    Male 2017-07-20 2020-08-29 13:54:00      15974
# 243      Abbie   Gillson  Female 2019-08-22 2020-11-02 06:11:00      24292
# 83       Abbye    Ollier  Female 2016-06-22 2020-09-07 22:48:00      11814
# 746       Abel     Neale    Male 2016-09-08 2020-06-04 20:39:00      20267
# 354       Abel    Puttan    Male 2019-05-26 2020-09-16 14:39:00      10158
# ..         ...       ...     ...        ...                 ...        ...
# 529    Zachery     Leads    Male 2018-09-21 2020-07-23 14:25:00       6506
# 339   Zebadiah  Sandeson    Male 2010-08-27 2020-07-14 10:03:00      18102
# 415    Zebulen    Stoyle    Male 2018-09-16 2020-07-25 15:15:00      14970
# 656      Zelig  Nicholas    Male 2018-12-13 2020-11-05 00:26:00       5162
# 152       Zita     Moran  Female 2016-02-26 2020-08-07 09:13:00      26361
#
#      posts  Influencer         Country
# ...

# %%
dup = insta.duplicated()
#insta[dup]
len(insta[dup])
# Out:
# 16

# %%
insta.drop_duplicates(inplace = True)
insta
# Out:
#     first name last name  gender   reg date          last login  followers  \
# 149       Abba     Savin    Male 2017-07-20 2020-08-29 13:54:00      15974
# 243      Abbie   Gillson  Female 2019-08-22 2020-11-02 06:11:00      24292
# 83       Abbye    Ollier  Female 2016-06-22 2020-09-07 22:48:00      11814
# 746       Abel     Neale    Male 2016-09-08 2020-06-04 20:39:00      20267
# 354       Abel    Puttan    Male 2019-05-26 2020-09-16 14:39:00      10158
# ..         ...       ...     ...        ...                 ...        ...
# 529    Zachery     Leads    Male 2018-09-21 2020-07-23 14:25:00       6506
# 339   Zebadiah  Sandeson    Male 2010-08-27 2020-07-14 10:03:00      18102
# 415    Zebulen    Stoyle    Male 2018-09-16 2020-07-25 15:15:00      14970
# 656      Zelig  Nicholas    Male 2018-12-13 2020-11-05 00:26:00       5162
# 152       Zita     Moran  Female 2016-02-26 2020-08-07 09:13:00      26361
#
#      posts  Influencer         Country
# ...

# %%
insta["gender"].value_counts()
# Out:
# gender
# Female    488
# Male      475
# Name: count, dtype: int64

# %%
insta["Country"].unique()
# Out:
# ['Japan', 'United Kingdom', 'Brazil', 'Canada', 'Australia', 'South Africa', 'United States', NaN]
# Categories (7, object): ['Australia', 'Brazil', 'Canada', 'Japan', 'South Africa', 'United Kingdom',
#                          'United States']

# %%
insta["gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
insta["Country"].nunique()
# Out:
# 7
