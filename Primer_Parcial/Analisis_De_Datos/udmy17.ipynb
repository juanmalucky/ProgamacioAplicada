# %%
import pandas as pd
fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")
fortune = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv", index_col = "Rank")
fortune
# Out:
#                               Company             Sector  \
# Rank
# 1                             Walmart          Retailing
# 2                         Exxon Mobil             Energy
# 3                  Berkshire Hathaway         Financials
# 4                               Apple         Technology
# 5                  UnitedHealth Group        Health Care
# ...                               ...                ...
# 996          SiteOne Landscape Supply        Wholesalers
# 997   Charles River Laboratories Intl        Health Care
# 998                         CoreLogic  Business Services
# 999                      Ensign Group        Health Care
# 1000                              HCP         Financials
#
#                                       Industry            Location  Revenues  \
# Rank
# 1                        General Merchandisers    Bentonville,  AR    500343
# 2                           Petroleum Refining         Irving,  TX    244363
# 3     Insurance: Property and Casualty (Stock)          Omaha,  NE    242137
# 4                  Computers, Office Equipment      Cupertino,  CA    229234
# 5      Health Care: Insurance and Managed Care     Minnetonka,  MN    201159
# ...                                        ...                 ...       ...
# 996                   Wholesalers: Diversified        Roswell,  GA      1862
# 997   Health Care: Pharmacy and Other Services     Wilmington,  MA      1858
# 998                    Financial Data Services         Irvine,  CA      1851
# 999            Health Care: Medical Facilities  Mission Viejo,  CA      1849
# 1000                               Real estate         Irvine,  CA      1848
#
#       Profits  Employees
# Rank
# 1        9862    2300000
# 2       19710      71200
# 3       44940     377000
# 4       48351     123000
# 5       10558     260000
# ...       ...        ...
# 996        54       3664
# 997       123      11800
# 998       152       5900
# 999        40      21301
# 1000      414        190
#
# [1000 rows x 7 columns]

# %%
fortune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Company    1000 non-null   object
#  1   Sector     1000 non-null   object
#  2   Industry   1000 non-null   object
#  3   Location   1000 non-null   object
#  4   Revenues   1000 non-null   int64
#  5   Profits    1000 non-null   int64
#  6   Employees  1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 62.5+ KB

# %%
fortune.head(3)
# Out:
#                  Company      Sector  \
# Rank
# 1                Walmart   Retailing
# 2            Exxon Mobil      Energy
# 3     Berkshire Hathaway  Financials
#
#                                       Industry          Location  Revenues  \
# Rank
# 1                        General Merchandisers  Bentonville,  AR    500343
# 2                           Petroleum Refining       Irving,  TX    244363
# 3     Insurance: Property and Casualty (Stock)        Omaha,  NE    242137
#
#       Profits  Employees
# Rank
# 1        9862    2300000
# 2       19710      71200
# 3       44940     377000

# %%
fortune.groupby('Sector')
x = fortune.groupby('Sector')
type(x)
x

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/fortune1000.csv")
sector = df.groupby('Sector')
df.head(5)
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3  Berkshire Hathaway   Financials
# 3     4               Apple   Technology
# 4     5  UnitedHealth Group  Health Care
#
#                                    Industry          Location  Revenues  \
# 0                     General Merchandisers  Bentonville,  AR    500343
# 1                        Petroleum Refining       Irving,  TX    244363
# 2  Insurance: Property and Casualty (Stock)        Omaha,  NE    242137
# 3               Computers, Office Equipment    Cupertino,  CA    229234
# 4   Health Care: Insurance and Managed Care   Minnetonka,  MN    201159
#
#    Profits  Employees
# 0     9862    2300000
# 1    19710      71200
# 2    44940     377000
# 3    48351     123000
# 4    10558     260000

# %%
sector

# %%
df["Sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Financials', 'Technology', 'Health Care',
#        'Wholesalers', 'Telecommunications', 'Motor Vehicles &  Parts',
#        'Food &  Drug Stores', 'Industrials', 'Aerospace &  Defense',
#        'Household Products', 'Transportation',
#        'Food, Beverages &  Tobacco', 'Chemicals', 'Media', 'Apparel',
#        'Materials', 'Hotels, Restaurants &  Leisure', 'Business Services',
#        'Engineering &  Construction'], dtype=object)

# %%
sector.size()
# Out:
# Sector
# Aerospace &  Defense               25
# Apparel                            14
# Business Services                  53
# Chemicals                          33
# Energy                            107
# Engineering &  Construction        27
# Financials                        155
# Food &  Drug Stores                12
# Food, Beverages &  Tobacco         37
# Health Care                        71
# Hotels, Restaurants &  Leisure     26
# Household Products                 28
# Industrials                        49
# Materials                          45
# Media                              25
# Motor Vehicles &  Parts            19
# Retailing                          77
# Technology                        103
# Telecommunications                 10
# Transportation                     40
# Wholesalers                        44
# dtype: int64

# %%
df["Sector"].value_counts()
# Out:
# Sector
# Financials                        155
# Energy                            107
# Technology                        103
# Retailing                          77
# Health Care                        71
# Business Services                  53
# Industrials                        49
# Materials                          45
# Wholesalers                        44
# Transportation                     40
# Food, Beverages &  Tobacco         37
# Chemicals                          33
# Household Products                 28
# Engineering &  Construction        27
# Hotels, Restaurants &  Leisure     26
# Media                              25
# Aerospace &  Defense               25
# Motor Vehicles &  Parts            19
# Apparel                            14
# Food &  Drug Stores                12
# Telecommunications                 10
# Name: count, dtype: int64

# %%
sector.first()
# Out:
#                                 Rank                 Company  \
# Sector
# Aerospace &  Defense              27                  Boeing
# Apparel                           89                    Nike
# Business Services                143           ManpowerGroup
# Chemicals                         47               DowDuPont
# Energy                             2             Exxon Mobil
# Engineering &  Construction      153                   Fluor
# Financials                         3      Berkshire Hathaway
# Food &  Drug Stores               17                  Kroger
# Food, Beverages &  Tobacco        45                 PepsiCo
# Health Care                        5      UnitedHealth Group
# Hotels, Restaurants &  Leisure   127  Marriott International
# Household Products                42        Procter & Gamble
# Industrials                       18        General Electric
# Materials                        124     International Paper
# Media                             55                  Disney
# Motor Vehicles &  Parts           10          General Motors
# Retailing                          1                 Walmart
# Technology                         4                   Apple
# Telecommunications                 9                    AT&T
# Transportation                    44                     UPS
# Wholesalers                        6                McKesson
#
#                                                                 Industry  \
# Sector
# Aerospace &  Defense                               Aerospace and Defense
# Apparel                                                          Apparel
# Business Services                                         Temporary Help
# Chemicals                                                      Chemicals
# Energy                                                Petroleum Refining
# Engineering &  Construction                    Engineering, Construction
# Financials                      Insurance: Property and Casualty (Stock)
# Food &  Drug Stores                                 Food and Drug Stores
# Food, Beverages &  Tobacco                        Food Consumer Products
# Health Care                      Health Care: Insurance and Managed Care
# Hotels, Restaurants &  Leisure                  Hotels, Casinos, Resorts
# Household Products                       Household and Personal Products
# Industrials                                         Industrial Machinery
# Materials                                          Packaging, Containers
# Media                                                      Entertainment
# Motor Vehicles &  Parts                         Motor Vehicles and Parts
# Retailing                                          General Merchandisers
# Technology                                   Computers, Office Equipment
# Telecommunications                                    Telecommunications
# Transportation                       Mail, Package, and Freight Delivery
# Wholesalers                                     Wholesalers: Health Care
#
#                                           Location  Revenues  Profits  \
# Sector
# Aerospace &  Defense                  Chicago,  IL     93392     8197
# Apparel                             Beaverton,  OR     34350     4240
# Business Services                   Milwaukee,  WI     21034      545
# Chemicals                       Midland,  Michigan     62683     1460
# Energy                                 Irving,  TX    244363    19710
# Engineering &  Construction            Irving,  TX     19521      191
# Financials                              Omaha,  NE    242137    44940
# Food &  Drug Stores                Cincinnati,  OH    122662     1907
# Food, Beverages &  Tobacco           Harrison,  NY     63525     4857
# Health Care                        Minnetonka,  MN    201159    10558
# Hotels, Restaurants &  Leisure       Bethesda,  MD     22894     1372
# Household Products                 Cincinnati,  OH     66217    15326
# Industrials                            Boston,  MA    122274    -5786
# Materials                             Memphis,  TN     23302     2144
# Media                                 Burbank,  CA     55137     8980
# Motor Vehicles &  Parts               Detroit,  MI    157311    -3864
# Retailing                         Bentonville,  AR    500343     9862
# Technology                          Cupertino,  CA    229234    48351
# Telecommunications                     Dallas,  TX    160546    29450
# Transportation                        Atlanta,  GA     65872     4910
# Wholesalers                                SF,  CA    198533     5070
#
#                                 Employees
# Sector
# Aerospace &  Defense               140800
# Apparel                             74400
# Business Services                   29000
# Chemicals                           98000
# Energy                              71200
# Engineering &  Construction         56706
# Financials                         377000
# Food &  Drug Stores                449000
# Food, Beverages &  Tobacco         263000
# Health Care                        260000
# Hotels, Restaurants &  Leisure     177000
# Household Products                  95000
# Industrials                        313000
# Materials                           56000
# Media                              199000
# Motor Vehicles &  Parts            180000
# Retailing                         2300000
# Technology                         123000
# Telecommunications                 254000
# Transportation                     346415
# Wholesalers                         64500

# %%
sector.last()
# Out:
#                                 Rank                      Company  \
# Sector
# Aerospace &  Defense             989  Aerojet Rocketdyne Holdings
# Apparel                          862         Wolverine World Wide
# Business Services                998                    CoreLogic
# Chemicals                        979                       Stepan
# Energy                           991     Superior Energy Services
# Engineering &  Construction      987                     TopBuild
# Financials                      1000                          HCP
# Food &  Drug Stores              942                        Freds
# Food, Beverages &  Tobacco       938                    Universal
# Health Care                      999                 Ensign Group
# Hotels, Restaurants &  Leisure   985                 Vail Resorts
# Household Products               968                  ACCO Brands
# Industrials                      982                      Rexnord
# Materials                        975             Summit Materials
# Media                            994                Tribune Media
# Motor Vehicles &  Parts          941          Tower International
# Retailing                        993              Childrens Place
# Technology                       992             VeriFone Systems
# Telecommunications               908          Zayo Group Holdings
# Transportation                   969        Echo Global Logistics
# Wholesalers                      996     SiteOne Landscape Supply
#
#                                                        Industry  \
# Sector
# Aerospace &  Defense                      Aerospace and Defense
# Apparel                                                 Apparel
# Business Services                       Financial Data Services
# Chemicals                                             Chemicals
# Energy                          Oil and Gas Equipment, Services
# Engineering &  Construction           Engineering, Construction
# Financials                                          Real estate
# Food &  Drug Stores                        Food and Drug Stores
# Food, Beverages &  Tobacco                              Tobacco
# Health Care                     Health Care: Medical Facilities
# Hotels, Restaurants &  Leisure         Hotels, Casinos, Resorts
# Household Products                  Home Equipment, Furnishings
# Industrials                                Industrial Machinery
# Materials                             Building Materials, Glass
# Media                                             Entertainment
# Motor Vehicles &  Parts                Motor Vehicles and Parts
# Retailing                          Specialty Retailers: Apparel
# Technology                              Financial Data Services
# Telecommunications                           Telecommunications
# Transportation                     Transportation and Logistics
# Wholesalers                            Wholesalers: Diversified
#
#                                           Location  Revenues  Profits  \
# Sector
# Aerospace &  Defense               El Segundo,  CA      1877      -10
# Apparel                              Rockford,  MI      2350        0
# Business Services                      Irvine,  CA      1851      152
# Chemicals                          Northfield,  IL      1925       91
# Energy                                Houston,  TX      1874     -206
# Engineering &  Construction     Daytona Beach,  FL      1906      158
# Financials                             Irvine,  CA      1848      414
# Food &  Drug Stores                   Memphis,  TN      2064     -141
# Food, Beverages &  Tobacco           Richmond,  VA      2071      106
# Health Care                     Mission Viejo,  CA      1849       40
# Hotels, Restaurants &  Leisure     Broomfield,  CO      1907      210
# Household Products                Lake Zurich,  IL      1949      131
# Industrials                         Milwaukee,  WI      1918       74
# Materials                              Denver,  CO      1933      121
# Media                                 Chicago,  IL      1867      194
# Motor Vehicles &  Parts               Livonia,  MI      2066       47
# Retailing                            Secaucus,  NJ      1870       84
# Technology                           San Jose,  CA      1871     -174
# Telecommunications                    Boulder,  CO      2200       85
# Transportation                        Chicago,  IL      1943       12
# Wholesalers                           Roswell,  GA      1862       54
#
#                                 Employees
# Sector
# Aerospace &  Defense                 5157
# Apparel                              3700
# Business Services                    5900
# Chemicals                            2096
# Energy                               6400
# Engineering &  Construction          8400
# Financials                            190
# Food &  Drug Stores                  7324
# Food, Beverages &  Tobacco          24000
# Health Care                         21301
# Hotels, Restaurants &  Leisure      20150
# Household Products                   6620
# Industrials                          8000
# Materials                            6000
# Media                                6000
# Motor Vehicles &  Parts              7600
# Retailing                            9800
# Technology                           5600
# Telecommunications                   3794
# Transportation                       2453
# Wholesalers                          3664

# %%
sector.get_group("Retailing")
sector.get_group("Health Care")
#sector.get_group("Energy")
# Out:
#      Rank                          Company       Sector  \
# 4       5               UnitedHealth Group  Health Care
# 6       7                       CVS Health  Health Care
# 24     25          Express Scripts Holding  Health Care
# 28     29                           Anthem  Health Care
# 36     37                Johnson & Johnson  Health Care
# ..    ...                              ...          ...
# 956   957          AMN Healthcare Services  Health Care
# 960   961               IDEXX Laboratories  Health Care
# 994   995        Healthcare Services Group  Health Care
# 996   997  Charles River Laboratories Intl  Health Care
# 998   999                     Ensign Group  Health Care
#
#                                      Industry            Location  Revenues  \
# 4     Health Care: Insurance and Managed Care     Minnetonka,  MN    201159
# 6    Health Care: Pharmacy and Other Services     Woonsocket,  RI    184765
# 24   Health Care: Pharmacy and Other Services      St. Louis,  MO    100065
# 28    Health Care: Insurance and Managed Care   Indianapolis,  IN     90040
# 36                            Pharmaceuticals  New Brunswick,  NJ     76450
# ..                                        ...                 ...       ...
# 956  Health Care: Pharmacy and Other Services      San Diego,  CA      1989
# 960            Medical Products and Equipment      Westbrook,  ME      1969
# 994  Health Care: Pharmacy and Other Services       Bensalem,  PA      1866
# 996  Health Care: Pharmacy and Other Services     Wilmington,  MA      1858
# 998           Health Care: Medical Facilities  Mission Viejo,  CA      1849
#
#      Profits  Employees
# 4      10558     260000
# 6       6622     203000
# 24      4517      26600
# 28      3842      56000
# 36      1300     134000
# ..       ...        ...
# 956      132       2980
# 960      263       7600
# 994       88      55000
# 996      123      11800
# 998       40      21301
#
# [71 rows x 8 columns]

# %%
df["Sector"] == "Energy"
mask = df["Sector"] == "Energy"
df[mask]
# Out:
#      Rank                    Company  Sector                         Industry  \
# 1       2                Exxon Mobil  Energy               Petroleum Refining
# 12     13                    Chevron  Energy               Petroleum Refining
# 27     28                Phillips 66  Energy               Petroleum Refining
# 30     31              Valero Energy  Energy               Petroleum Refining
# 40     41         Marathon Petroleum  Energy               Petroleum Refining
# ..    ...                        ...     ...                              ...
# 953   954       California Resources  Energy     Mining, Crude-Oil Production
# 976   977        Ferrellgas Partners  Energy                           Energy
# 979   980  Oceaneering International  Energy  Oil and Gas Equipment, Services
# 980   981             Cimarex Energy  Energy     Mining, Crude-Oil Production
# 990   991   Superior Energy Services  Energy  Oil and Gas Equipment, Services
#
#                Location  Revenues  Profits  Employees
# 1           Irving,  TX    244363    19710      71200
# 12       San Ramon,  CA    134533     9195      51900
# 27         Houston,  TX     91568     5106      14600
# 30     San Antonio,  TX     88407     4065      10015
# 40         Findlay,  OH     67610     3432      43800
# ..                  ...       ...      ...        ...
# 953    Los Angeles,  CA      2006     -266       1450
# 976  Overland Park,  KS      1930      -55       3891
# 979        Houston,  TX      1922      166       8200
# 980         Denver,  CO      1918      494        910
# 990        Houston,  TX      1874     -206       6400
#
# [107 rows x 8 columns]

# %%
#df.set_index("Rank", inplace = True)
df
# Out:
#      Rank                          Company             Sector  \
# 0       1                          Walmart          Retailing
# 1       2                      Exxon Mobil             Energy
# 2       3               Berkshire Hathaway         Financials
# 3       4                            Apple         Technology
# 4       5               UnitedHealth Group        Health Care
# ..    ...                              ...                ...
# 995   996         SiteOne Landscape Supply        Wholesalers
# 996   997  Charles River Laboratories Intl        Health Care
# 997   998                        CoreLogic  Business Services
# 998   999                     Ensign Group        Health Care
# 999  1000                              HCP         Financials
#
#                                      Industry            Location  Revenues  \
# 0                       General Merchandisers    Bentonville,  AR    500343
# 1                          Petroleum Refining         Irving,  TX    244363
# 2    Insurance: Property and Casualty (Stock)          Omaha,  NE    242137
# 3                 Computers, Office Equipment      Cupertino,  CA    229234
# 4     Health Care: Insurance and Managed Care     Minnetonka,  MN    201159
# ..                                        ...                 ...       ...
# 995                  Wholesalers: Diversified        Roswell,  GA      1862
# 996  Health Care: Pharmacy and Other Services     Wilmington,  MA      1858
# 997                   Financial Data Services         Irvine,  CA      1851
# 998           Health Care: Medical Facilities  Mission Viejo,  CA      1849
# 999                               Real estate         Irvine,  CA      1848
#
#      Profits  Employees
# 0       9862    2300000
# 1      19710      71200
# 2      44940     377000
# 3      48351     123000
# 4      10558     260000
# ..       ...        ...
# 995       54       3664
# 996      123      11800
# 997      152       5900
# 998       40      21301
# 999      414        190
#
# [1000 rows x 8 columns]

# %%
sector.sum()
sector["Employees"].sum()
sector["Employees"].mean()
# Out:
# Sector
# Aerospace &  Defense               40404.960000
# Apparel                            25407.071429
# Business Services                  30075.452830
# Chemicals                          14364.242424
# Energy                              9170.158879
# Engineering &  Construction        15583.148148
# Financials                         22581.412903
# Food &  Drug Stores               116506.166667
# Food, Beverages &  Tobacco         29170.702703
# Health Care                        41847.732394
# Hotels, Restaurants &  Leisure     88628.346154
# Household Products                 24103.428571
# Industrials                        31961.428571
# Materials                          14527.800000
# Media                              21839.400000
# Motor Vehicles &  Parts            49662.210526
# Retailing                          88320.233766
# Technology                         31036.961165
# Telecommunications                 78560.900000
# Transportation                     41302.825000
# Wholesalers                        16913.068182
# Name: Employees, dtype: float64

# %%
sector.agg({"Revenues" : "mean", "Profits" : "mean", "Employees" : "sum"})
sector.agg({"Revenues" : ["mean", "max"], "Profits" : "mean", "Employees" : "sum"})
sector.agg({"Revenues" : ["mean", "max"], "Profits" : ["max", "min"], "Employees" : "sum"})
# Out:
#                                     Revenues         Profits       Employees
#                                         mean     max     max   min       sum
# Sector
# Aerospace &  Defense            15353.400000   93392    8197   -74   1010124
# Apparel                          7225.500000   34350    4240  -479    355699
# Business Services                5963.962264   21034    6699  -558   1593999
# Chemicals                        7610.636364   62683    3000  -297    474020
# Energy                          14425.299065  244363   19710 -5723    981207
# Engineering &  Construction      6399.333333   19521    1038  -333    420745
# Financials                      15757.935484  242137   44940 -6798   3500119
# Food &  Drug Stores             33789.000000  122662    4078  -374   1398074
# Food, Beverages &  Tobacco      13790.054054   63525   10999  -287   1079316
# Health Care                     21239.309859  201159   21308 -2459   2971189
# Hotels, Restaurants &  Leisure   6916.346154   22894    5192  -375   2304337
# Household Products               8277.821429   66217   15326 -1054    674896
# Industrials                     10615.102041  122274    4858 -5786   1566110
# Materials                        6184.400000   23302    2144  -258    653751
# Media                            9219.480000   55137    8980  -738    545985
# Motor Vehicles &  Parts         22817.631579  157311    7602 -3864    943582
# Retailing                       21874.714286  500343    9862 -1068   6800658
# Technology                      13347.786408  229234   48351 -3728   3196807
# Telecommunications              46695.900000  160546   30101 -2117    785609
# Transportation                  11379.000000   65872   10712  -107   1652113
# Wholesalers                     20185.204545  198533    5070  -267    744175

# %%
fortune = df
fortune
sectors = fortune.groupby('Sector')
fortune
# Out:
#      Rank                          Company             Sector  \
# 0       1                          Walmart          Retailing
# 1       2                      Exxon Mobil             Energy
# 2       3               Berkshire Hathaway         Financials
# 3       4                            Apple         Technology
# 4       5               UnitedHealth Group        Health Care
# ..    ...                              ...                ...
# 995   996         SiteOne Landscape Supply        Wholesalers
# 996   997  Charles River Laboratories Intl        Health Care
# 997   998                        CoreLogic  Business Services
# 998   999                     Ensign Group        Health Care
# 999  1000                              HCP         Financials
#
#                                      Industry            Location  Revenues  \
# 0                       General Merchandisers    Bentonville,  AR    500343
# 1                          Petroleum Refining         Irving,  TX    244363
# 2    Insurance: Property and Casualty (Stock)          Omaha,  NE    242137
# 3                 Computers, Office Equipment      Cupertino,  CA    229234
# 4     Health Care: Insurance and Managed Care     Minnetonka,  MN    201159
# ..                                        ...                 ...       ...
# 995                  Wholesalers: Diversified        Roswell,  GA      1862
# 996  Health Care: Pharmacy and Other Services     Wilmington,  MA      1858
# 997                   Financial Data Services         Irvine,  CA      1851
# 998           Health Care: Medical Facilities  Mission Viejo,  CA      1849
# 999                               Real estate         Irvine,  CA      1848
#
#      Profits  Employees
# 0       9862    2300000
# 1      19710      71200
# 2      44940     377000
# 3      48351     123000
# 4      10558     260000
# ..       ...        ...
# 995       54       3664
# 996      123      11800
# 997      152       5900
# 998       40      21301
# 999      414        190
#
# [1000 rows x 8 columns]

# %%
sector.size()
# Out:
# Sector
# Aerospace &  Defense               25
# Apparel                            14
# Business Services                  53
# Chemicals                          33
# Energy                            107
# Engineering &  Construction        27
# Financials                        155
# Food &  Drug Stores                12
# Food, Beverages &  Tobacco         37
# Health Care                        71
# Hotels, Restaurants &  Leisure     26
# Household Products                 28
# Industrials                        49
# Materials                          45
# Media                              25
# Motor Vehicles &  Parts            19
# Retailing                          77
# Technology                        103
# Telecommunications                 10
# Transportation                     40
# Wholesalers                        44
# dtype: int64

# %%
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Company, Sector, Industry, Location, Revenues, Profits, Employees]
# Index: []

# %%
for sector, values in sectors:
  company_with_highest_profit = values.nlargest(1, "Profits")
  df = df.append(company_with_highest_profit)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5de552f4340c> in <cell line: 1>()
#       1 for sector, values in sectors:
#       2   company_with_highest_profit = values.nlargest(1, "Profits")
# ----> 3   df = df.append(company_with_highest_profit)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'
