# %%
import pandas as pd

# %%
data = {"name": ["Sally", "Jhon", "Kim"], "age": [4, 6 ,7], "gender": ["female", "male", "male"]}
# Diccionario con datos de nombre, edad y género

# %%
pd.DataFrame(data)
# Out:
#     name  age  gender
# 0  Sally    4  female
# 1   Jhon    6    male
# 2    Kim    7    male

# %%
pd.DataFrame(data, index = ["Kid1", "Kid2", "Kid3"])# Se crea un DataFrame con índices personalizados
# Out:
#        name  age  gender
# Kid1  Sally    4  female
# Kid2   Jhon    6    male
# Kid3    Kim    7    male
