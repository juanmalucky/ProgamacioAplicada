# %%
import pandas as pd
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"
#covid = pd.read_csv(url)
covid = pd.read_csv(url)
covid.head()
# Se carga un archivo CSV desde una URL con datos de COVID-19 en Nueva York
# Out:
#           date_of_interest  case_count  probable_case_count  \
# 0  2020-02-29T00:00:00.000           1                    0
# 1  2020-03-01T00:00:00.000           0                    0
# 2  2020-03-02T00:00:00.000           0                    0
# 3  2020-03-03T00:00:00.000           1                    0
# 4  2020-03-04T00:00:00.000           5                    0
#
#    hospitalized_count  death_count  case_count_7day_avg  \
# 0                   1            0                    0
# 1                   1            0                    0
# 2                   2            0                    0
# 3                   7            0                    0
# 4                   2            0                    0
#
#    all_case_count_7day_avg  hosp_count_7day_avg  death_count_7day_avg  \
# 0                        0                    0                     0
# 1                        0                    0                     0
# ...

# %%
covid.info()
# Se muestran los primeros datos y algo de información general del archivo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_of_interest                 1000 non-null   object
#  1   case_count                       1000 non-null   int64
#  2   probable_case_count              1000 non-null   int64
#  3   hospitalized_count               1000 non-null   int64
#  4   death_count                      1000 non-null   int64
#  5   case_count_7day_avg              1000 non-null   int64
#  6   all_case_count_7day_avg          1000 non-null   int64
#  7   hosp_count_7day_avg              1000 non-null   int64
#  8   death_count_7day_avg             1000 non-null   int64
#  9   bx_case_count                    1000 non-null   int64
#  10  bx_probable_case_count           1000 non-null   int64
#  11  bx_hospitalized_count            1000 non-null   int64
# ...

# %%
covid.to_csv('NYC_covid_cases.csv')
# Se guardan los datos completos en un archivo local

# %%
covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])
# Se guarda otro archivo local solo con algunas columnas seleccionadas
