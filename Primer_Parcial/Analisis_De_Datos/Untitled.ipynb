# %%
import pandas as pd
nba = pd.read_excel('Nba Teams.xlsx')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        484 non-null    object
#  1   Team        484 non-null    object
#  2   Division    484 non-null    object
#  3   Position    484 non-null    object
#  4   Height      470 non-null    object
#  5   Weight      484 non-null    float64
#  6   Birth_Date  484 non-null    datetime64[ns]
#  7   College     422 non-null    object
#  8   Salary      434 non-null    float64
#  9   Country     484 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 39.0+ KB

# %%
nba["Salary"].fillna(0, inplace = True)
nba["Height"].fillna("Missing", inplace = True)
nba["Height"].fillna("Missing", inplace = True)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        484 non-null    object
#  1   Team        484 non-null    object
#  2   Division    484 non-null    object
#  3   Position    484 non-null    object
#  4   Height      498 non-null    object
#  5   Weight      484 non-null    float64
#  6   Birth_Date  484 non-null    datetime64[ns]
#  7   College     422 non-null    object
#  8   Salary      498 non-null    float64
#  9   Country     484 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 39.0+ KB

# %%
nba
# Out:
#                   Name                Team   Division Position   Height  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G      6'6
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G  Missing
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F      6'9
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F      6'8
# 4         Clint Capela       Atlanta Hawks  SouthEast        C     6'10
# ..                 ...                 ...        ...      ...      ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F      6'8
# 494                NaN                 NaN        NaN      NaN  Missing
# 495  Russell Westbrook  Washington Wizards  SouthEast        G      6'3
# 496      Thomas Bryant  Washington Wizards  SouthEast        C     6'10
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F      6'6
#
#      Weight Birth_Date          College      Salary Country
# ...

# %%
nba["Salary"].astype("int")
nba
# Out:
#                   Name                Team   Division Position   Height  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G      6'6
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G  Missing
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F      6'9
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F      6'8
# 4         Clint Capela       Atlanta Hawks  SouthEast        C     6'10
# ..                 ...                 ...        ...      ...      ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F      6'8
# 494                NaN                 NaN        NaN      NaN  Missing
# 495  Russell Westbrook  Washington Wizards  SouthEast        G      6'3
# 496      Thomas Bryant  Washington Wizards  SouthEast        C     6'10
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F      6'6
#
#      Weight Birth_Date          College      Salary Country
# ...

# %%
nba["Salary"] = nba["Salary"].astype("int")
nba
# Out:
#                   Name                Team   Division Position   Height  \
# 0    Bogdan Bogdanovic       Atlanta Hawks  SouthEast        G      6'6
# 1      Brandon Goodwin       Atlanta Hawks  SouthEast        G  Missing
# 2       Bruno Fernando       Atlanta Hawks  SouthEast        F      6'9
# 3          Cam Reddish       Atlanta Hawks  SouthEast        F      6'8
# 4         Clint Capela       Atlanta Hawks  SouthEast        C     6'10
# ..                 ...                 ...        ...      ...      ...
# 493      Rui Hachimura  Washington Wizards  SouthEast        F      6'8
# 494                NaN                 NaN        NaN      NaN  Missing
# 495  Russell Westbrook  Washington Wizards  SouthEast        G      6'3
# 496      Thomas Bryant  Washington Wizards  SouthEast        C     6'10
# 497     Troy Brown Jr.  Washington Wizards  SouthEast      G-F      6'6
#
#      Weight Birth_Date          College    Salary Country
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        484 non-null    object
#  1   Team        484 non-null    object
#  2   Division    484 non-null    object
#  3   Position    484 non-null    object
#  4   Height      498 non-null    object
#  5   Weight      484 non-null    float64
#  6   Birth_Date  484 non-null    datetime64[ns]
#  7   College     422 non-null    object
#  8   Salary      498 non-null    int32
#  9   Country     484 non-null    object
# dtypes: datetime64[ns](1), float64(1), int32(1), object(7)
# memory usage: 37.1+ KB
