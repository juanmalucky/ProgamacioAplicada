# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Fruits.csv")
df.head(10)
# Out:
#       type         color  price usd
# 0  Peaches        Yellow       2.05
# 1  Peaches           Red       1.63
# 2  Peaches         Brown       2.58
# 3   Apples           Red       3.05
# 4   Apples        Yellow       2.50
# 5   Apples         Green       1.83
# 6   Apples          Pink       1.18
# 7   Apples  Golden Brown       1.05
# 8  Oranges           Red       1.91
# 9  Oranges        Yellow       2.16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   type       76 non-null     object
#  1   color      76 non-null     object
#  2   price usd  76 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.9+ KB

# %%
df.set_index(["type", "color"])
# Out:
#                      price usd
# type         color
# Peaches      Yellow       2.05
#              Red          1.63
#              Brown        2.58
# Apples       Red          3.05
#              Yellow       2.50
# ...                        ...
# Passionfruit Red          1.99
#              Purple       1.23
# Grapefruit   Orange       2.24
#              Pink         1.86
#              Green        1.08
#
# [76 rows x 1 columns]

# %%
df.set_index(["type", "color"], inplace = True)
df
# Out:
#                      price usd
# type         color
# Peaches      Yellow       2.05
#              Red          1.63
#              Brown        2.58
# Apples       Red          3.05
#              Yellow       2.50
# ...                        ...
# Passionfruit Red          1.99
#              Purple       1.23
# Grapefruit   Orange       2.24
#              Pink         1.86
#              Green        1.08
#
# [76 rows x 1 columns]

# %%
df.index
# Out:
# MultiIndex([(       'Peaches',       'Yellow'),
#             (       'Peaches',          'Red'),
#             (       'Peaches',        'Brown'),
#             (        'Apples',          'Red'),
#             (        'Apples',       'Yellow'),
#             (        'Apples',        'Green'),
#             (        'Apples',         'Pink'),
#             (        'Apples', 'Golden Brown'),
#             (       'Oranges',          'Red'),
#             (       'Oranges',       'Yellow'),
#             (       'Oranges',        'Green'),
#             (   'Raspberries',        'Black'),
#             (   'Raspberries',        'Brown'),
#             (   'Raspberries',          'Red'),
#             (   'Raspberries',         'Pink'),
#             (   'Raspberries',       'Yellow'),
#             (   'Raspberries',       'Purple'),
#             (  'Strawberries',         'Blue'),
#             (  'Strawberries',          'Red'),
#             (  'Strawberries',       'Purple'),
#             (  'Blackberries',        'Black'),
#             (  'Blackberries',       'Purple'),
#             (   'Yellow Figs',          'Red'),
#             (   'Yellow Figs',       'Orange'),
#             (   'Yellow Figs',       'Yellow'),
#             (       'Peppers',         'Pink'),
#             (       'Mangoes',        'Green'),
#             (       'Mangoes',       'Yellow'),
#             (       'Mangoes',          'Red'),
#             (       'Papayas',       'Yellow'),
#             (       'Papayas',        'Green'),
#             (       'Papayas',          'Red'),
#             (    'Pineapples',        'Green'),
#             (    'Pineapples',       'Yellow'),
#             (    'Pineapples',        'Brown'),
#             (         'Lemon',        'Green'),
#             (         'Lemon',       'Yellow'),
#             (         'Lemon',        'Brown'),
#             (       'Bananas',        'Green'),
#             (       'Bananas',       'Yellow'),
#             (    'Tangerines',          'Red'),
#             (    'Tangerines',       'Yellow'),
#             (    'Tangerines',        'Brown'),
#             (    'Tangerines',        'Green'),
#             (     'Avocadoes',        'Green'),
#             (     'Avocadoes',        'Brown'),
#             (       'Raisins',       'Purple'),
#             (        'Grapes',       'Purple'),
#             (        'Grapes',          'Red'),
#             (        'Grapes',        'Green'),
#             (        'Grapes',        'Brown'),
#             (         'Pears',       'Yellow'),
#             (         'Pears',        'Brown'),
#             (         'Pears',         'Pink'),
#             ('Black Currants',         'Blue'),
#             ('Black Currants',       'Purple'),
#             (    'Watermelon',          'Red'),
#             (    'Watermelon',         'Pink'),
#             (    'Watermelon', 'Golden Brown'),
#             (   'Cranberries',          'Red'),
#             (          'Kiwi',        'Green'),
#             (          'Kiwi', 'Golden Brown'),
#             (   'Blueberries',         'Blue'),
#             (    'Nectarines',       'Yellow'),
#             (    'Nectarines',       'Orange'),
#             (          'Plum',         'Blue'),
#             (          'Plum',       'Purple'),
#             (          'Plum',        'Brown'),
#             (  'Elderberries',         'Blue'),
#             (        'Cherry',       'Purple'),
#             (        'Cherry',          'Red'),
#             (  'Passionfruit',          'Red'),
#             (  'Passionfruit',       'Purple'),
#             (    'Grapefruit',       'Orange'),
#             (    'Grapefruit',         'Pink'),
#             (    'Grapefruit',        'Green')],
#            names=['type', 'color'])

# %%
df.index.get_level_values(0)
df.index.get_level_values(1)
# Out:
# Index(['Yellow', 'Red', 'Brown', 'Red', 'Yellow', 'Green', 'Pink',
#        'Golden Brown', 'Red', 'Yellow', 'Green', 'Black', 'Brown', 'Red',
#        'Pink', 'Yellow', 'Purple', 'Blue', 'Red', 'Purple', 'Black', 'Purple',
#        'Red', 'Orange', 'Yellow', 'Pink', 'Green', 'Yellow', 'Red', 'Yellow',
#        'Green', 'Red', 'Green', 'Yellow', 'Brown', 'Green', 'Yellow', 'Brown',
#        'Green', 'Yellow', 'Red', 'Yellow', 'Brown', 'Green', 'Green', 'Brown',
#        'Purple', 'Purple', 'Red', 'Green', 'Brown', 'Yellow', 'Brown', 'Pink',
#        'Blue', 'Purple', 'Red', 'Pink', 'Golden Brown', 'Red', 'Green',
#        'Golden Brown', 'Blue', 'Yellow', 'Orange', 'Blue', 'Purple', 'Brown',
#        'Blue', 'Purple', 'Red', 'Red', 'Purple', 'Orange', 'Pink', 'Green'],
#       dtype='object', name='color')

# %%
df = pd.read_csv("/content/drive/MyDrive/udmy/dataAnalisys/Fruits.csv", index_col=["type", "color"])
df.head(10)
# Out:
#                       price usd
# type    color
# Peaches Yellow             2.05
#         Red                1.63
#         Brown              2.58
# Apples  Red                3.05
#         Yellow             2.50
#         Green              1.83
#         Pink               1.18
#         Golden Brown       1.05
# Oranges Red                1.91
#         Yellow             2.16

# %%
df.sort_index()
df.sort_index(ascending  = False)
# Out:
#                           price usd
# type        color
# Yellow Figs Yellow             1.24
#             Red                3.38
#             Orange             2.42
# Watermelon  Red                2.47
#             Pink               3.30
# ...                             ...
# Apples      Yellow             2.50
#             Red                3.05
#             Pink               1.18
#             Green              1.83
#             Golden Brown       1.05
#
# [76 rows x 1 columns]

# %%
df.sort_index(level = 0)
df.sort_index(level = 1)
# Out:
#                        price usd
# type           color
# Blackberries   Black        2.65
# Raspberries    Black        1.09
# Black Currants Blue         1.45
# Blueberries    Blue         2.80
# Elderberries   Blue         2.13
# ...                          ...
# Pears          Yellow       2.38
# Pineapples     Yellow       1.74
# Raspberries    Yellow       2.59
# Tangerines     Yellow       1.14
# Yellow Figs    Yellow       1.24
#
# [76 rows x 1 columns]

# %%
df["price usd"]
df["price in pounds"] = df["price usd"]*0.71
df
# Out:
#                      price usd  price in pounds
# type         color
# Peaches      Yellow       2.05           1.4555
#              Red          1.63           1.1573
#              Brown        2.58           1.8318
# Apples       Red          3.05           2.1655
#              Yellow       2.50           1.7750
# ...                        ...              ...
# Passionfruit Red          1.99           1.4129
#              Purple       1.23           0.8733
# Grapefruit   Orange       2.24           1.5904
#              Pink         1.86           1.3206
#              Green        1.08           0.7668
#
# [76 rows x 2 columns]

# %%
df.loc["Apples"]
df.loc["Apples", "Green"]
# Out:
# price usd          1.8300
# price in pounds    1.2993
# Name: (Apples, Green), dtype: float64

# %%
df.loc[("Apples", "Green"), "price usd"]
# Out:
# 1.83

# %%
df.stack()
df.stack().to_frame()
df2 = df.stack().to_frame()
df2
# Out:
#                                         0
# type       color
# Peaches    Yellow price usd        2.0500
#                   price in pounds  1.4555
#            Red    price usd        1.6300
#                   price in pounds  1.1573
#            Brown  price usd        2.5800
# ...                                   ...
# Grapefruit Orange price in pounds  1.5904
#            Pink   price usd        1.8600
#                   price in pounds  1.3206
#            Green  price usd        1.0800
#                   price in pounds  0.7668
#
# [152 rows x 1 columns]

# %%
df2.unstack()
# Out:
#                                  0
#                          price usd price in pounds
# type        color
# Apples      Golden Brown      1.05          0.7455
#             Green             1.83          1.2993
#             Pink              1.18          0.8378
#             Red               3.05          2.1655
#             Yellow            2.50          1.7750
# ...                            ...             ...
# Watermelon  Pink              3.30          2.3430
#             Red               2.47          1.7537
# Yellow Figs Orange            2.42          1.7182
#             Red               3.38          2.3998
#             Yellow            1.24          0.8804
#
# [76 rows x 2 columns]
